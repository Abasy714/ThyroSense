# %% [markdown]
# # ThyroSense — ML Pipeline

# %% [markdown]
# ## Stage 1: Data Loading

# %%
import pandas as pd
import numpy as np

# Load the thyroid dataset
# Place the raw CSV in notebook/data/ before running
df = pd.read_csv('data/thyroid.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## Stage 2: Data Cleaning

# %% [markdown]
# ## Stage 3: Univariate EDA

# %% [markdown]
# ## Stage 4: Multivariate EDA

# %% [markdown]
# ## Stage 5: Clustering

# %% [markdown]
# ## Stage 6: Dimensionality Reduction

# %% [markdown]
# ## Stage 7: Class Imbalance (SMOTE)

# %% [markdown]
# ## Stage 8: Machine Learning

# %% [markdown]
# ## Stage 9: Model Export
